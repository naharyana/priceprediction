# %% [markdown]
# ## 1. Load Required Libraries

# %%
import pandas as pd
import src.util as utils
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 2. Load Configuration File

# %%
config = utils.load_config()
config
# Out:
# {'dataset_raw_path': 'data/raw/laptop_price_data.csv',
#  'dataset_path': 'data/processed/raw_dataset.pkl',
#  'test_size': 0.3,
#  'valid_size': 0.5,
#  'train_set_path': ['data/processed/x_train.pkl',
#   'data/processed/y_train.pkl'],
#  'valid_set_path': ['data/processed/x_valid.pkl',
#   'data/processed/y_valid.pkl'],
#  'test_set_path': ['data/processed/x_test.pkl', 'data/processed/y_test.pkl'],
#  'train_clean_path': ['data/processed/x_train_clean.pkl',
#   'data/processed/y_train_clean.pkl'],
#  'valid_clean_path': ['data/processed/x_valid_clean.pkl',
#   'data/processed/y_valid_clean.pkl'],
#  'test_clean_path': ['data/processed/x_test_clean.pkl',
#   'data/processed/y_test_clean.pkl'],
#  'production_model_path': 'models/production_model.pkl',
#  'training_log_path': 'log/training_log.json',
#  'standardizer_path': 'data/output/standardizer.pkl',
#  'ohe_path': 'data/output/one_hot_encoder.pkl',
#  'preprocessor_path': 'data/output/preprocessor.pkl',
#  'label': 'Price',
#  'predictors': ['Company',
#   'TypeName',
#   'OpSys',
#   'Cpu',
#   'Inches',
#   'Ram',
#   'Memory',
#   'Gpu',
#   'Weight',
#   'ScreenResolution',
#   'HDD',
#   'SSD',
#   'Hybrid',
#   'Flash_Storage'],
#  'numerical_columns': ['Inches',
#   'Ram',
#   'HDD',
#   'SSD',
#   'Hybrid',
#   'Flash_Storage',
#   'Gpu',
#   'Weight',
#   'X_res',
#   'Y_res'],
#  'print_debug': True,
#  'range_company': ['Lenovo',
#   'Dell',
#   'HP',
#   'Asus',
#   'Acer',
#   'Toshiba',
#   'MSI',
#   'Apple',
#   'Samsung',
#   'Razer',
#   'Vero',
#   'Chuwi',
#   'Mediacom',
#   'Microsoft',
#   'Google',
#   'Xiaomi',
#   'Huawei',
#   'LG',
#   'Fujitsu']}

# %% [markdown]
# ## 3. Load Dataset

# %%
dataset = pd.read_csv(config["dataset_raw_path"])
dataset.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram             Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128 SSD
# 1        Intel Core i5 1.8GHz   8GB  128 Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256 SSD
# 3        Intel Core i7 2.7GHz  16GB            512 SSD
# 4        Intel Core i5 3.1GHz   8GB            256 SSD
#
#                             Gpu  OpSys  Weight        Price  HDD  SSD  Hybrid  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832    0  128       0
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232    0    0       0
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000    0  256       0
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360    0  512       0
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# 2              0
# 3              0
# 4              0

# %%
dataset["Company"].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
dataset["Flash_Storage"].value_counts()
# Out:
# 0      1228
# 32       38
# 64       16
# 256       8
# 16        7
# 128       4
# 512       2
# Name: Flash_Storage, dtype: int64

# %% [markdown]
# ## 4. Data Validation

# %%
dataset.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# HDD                 0
# SSD                 0
# Hybrid              0
# Flash_Storage       0
# dtype: int64

# %%
dataset.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# HDD                   int64
# SSD                   int64
# Hybrid                int64
# Flash_Storage         int64
# dtype: object

# %%
def check_data(input_data, params):
    # check range of data
    assert set(input_data.Company).issubset(set(params["range_company"])), "an error occurs in Company range."

# %%
check_data(dataset, config)

# %% [markdown]
# ## 6. Data Splitting

# %%
x = dataset[config["predictors"]].copy()
y = dataset[config["label"]].copy()

# %%
x
# Out:
#      Company            TypeName       OpSys  \
# 0      Apple           Ultrabook       macOS
# 1      Apple           Ultrabook       macOS
# 2         HP            Notebook       No OS
# 3      Apple           Ultrabook       macOS
# 4      Apple           Ultrabook       macOS
# ...      ...                 ...         ...
# 1298  Lenovo  2 in 1 Convertible  Windows 10
# 1299  Lenovo  2 in 1 Convertible  Windows 10
# 1300  Lenovo            Notebook  Windows 10
# 1301      HP            Notebook  Windows 10
# 1302    Asus            Notebook  Windows 10
#
#                                        Cpu  Inches   Ram             Memory  \
# 0                     Intel Core i5 2.3GHz    13.3   8GB            128 SSD
# 1                     Intel Core i5 1.8GHz    13.3   8GB  128 Flash Storage
# 2               Intel Core i5 7200U 2.5GHz    15.6   8GB            256 SSD
# 3                     Intel Core i7 2.7GHz    15.4  16GB            512 SSD
# 4                     Intel Core i5 3.1GHz    13.3   8GB            256 SSD
# ...                                    ...     ...   ...                ...
# 1298            Intel Core i7 6500U 2.5GHz    14.0   4GB            128 SSD
# 1299            Intel Core i7 6500U 2.5GHz    13.3  16GB            512 SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz    14.0   2GB   64 Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz    15.6   6GB           1000 HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz    15.6   4GB            500 HDD
#
#                                Gpu  Weight  \
# 0     Intel Iris Plus Graphics 640  1.37kg
# 1           Intel HD Graphics 6000  1.34kg
# 2            Intel HD Graphics 620  1.86kg
# 3               AMD Radeon Pro 455  1.83kg
# 4     Intel Iris Plus Graphics 650  1.37kg
# ...                            ...     ...
# 1298         Intel HD Graphics 520   1.8kg
# 1299         Intel HD Graphics 520   1.3kg
# 1300             Intel HD Graphics   1.5kg
# 1301            AMD Radeon R5 M330  2.19kg
# 1302             Intel HD Graphics   2.2kg
#
#                                 ScreenResolution   HDD  SSD  Hybrid  \
# 0             IPS Panel Retina Display 2560x1600     0  128       0
# 1                                       1440x900     0    0       0
# 2                              Full HD 1920x1080     0  256       0
# 3             IPS Panel Retina Display 2880x1800     0  512       0
# 4             IPS Panel Retina Display 2560x1600     0  256       0
# ...                                          ...   ...  ...     ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080     0  128       0
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800     0  512       0
# 1300                                    1366x768     0    0       0
# 1301                                    1366x768  1000    0       0
# 1302                                    1366x768   500    0       0
#
#       Flash_Storage
# 0                 0
# 1               128
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 1298              0
# 1299              0
# 1300             64
# 1301              0
# 1302              0
#
# [1303 rows x 14 columns]

# %%
y
# Out:
# 0        71378.6832
# 1        47895.5232
# 2        30636.0000
# 3       135195.3360
# 4        96095.8080
#            ...
# 1298     33992.6400
# 1299     79866.7200
# 1300     12201.1200
# 1301     40705.9200
# 1302     19660.3200
# Name: Price, Length: 1303, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
x_valid, x_test, y_valid, y_test = train_test_split(x_test, y_test, test_size = 0.5, random_state = 42)

# %%
utils.pickle_dump(dataset, config["dataset_path"])

utils.pickle_dump(x_train, config["train_set_path"][0])
utils.pickle_dump(y_train, config["train_set_path"][1])

utils.pickle_dump(x_valid, config["valid_set_path"][0])
utils.pickle_dump(y_valid, config["valid_set_path"][1])

utils.pickle_dump(x_test, config["test_set_path"][0])
utils.pickle_dump(y_test, config["test_set_path"][1])
